# %%
import pandas as pd
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
import plotly.graph_objs as go

# %%
init_notebook_mode(connected=True)
# Out:
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>

# %%
pesquisa = pd.read_csv("../data/raw/pesquisa_preco_2018.csv", dtype={'valor_compra': float, 'valor_venda': float}, error_bad_lines=False, encoding='latin-1', warn_bad_lines=False)
pesquisa.head(5)
# Out:
#    valor_compra  valor_venda     unidade municipio regiao estado  \
# 0           NaN        3.579  R$ / litro  BRASILIA     CO     DF
# 1           NaN        3.590  R$ / litro  BRASILIA     CO     DF
# 2           NaN        3.699  R$ / litro  BRASILIA     CO     DF
# 3           NaN        3.199  R$ / litro  BRASILIA     CO     DF
# 4         3.218        3.559  R$ / litro  BRASILIA     CO     DF
#
#                        bandeira produto               razao_social_revenda  \
# 0                        BRANCA  DIESEL    EUROGAS-POSTOS DE SERVIÇOS LTDA
# 1                        BRANCA  DIESEL  JARJOUR VEICULOS E PETRÓLEO LTDA.
# 2                      IPIRANGA  DIESEL              AUTO POSTO BRAGA LTDA
# 3                      IPIRANGA  DIESEL    AUTO POSTO SAO JUDAS TADEU LTDA
# 4  PETROBRAS DISTRIBUIDORA S.A.  DIESEL             AUTO POSTO CHAVES LTDA
#
#   data_coleta
# 0  03/01/2018
# 1  03/01/2018
# 2  03/01/2018
# 3  03/01/2018
# 4  03/01/2018

# %%
pesquisa['data_coleta'] = pd.to_datetime(pesquisa['data_coleta'], format='%d/%m/%Y')
#modifica o index do dataframe para data de cadastro
pesquisa.set_index('data_coleta', inplace=True)
#ordena em forma ascendente o index
pesquisa.sort_index(inplace=True, ascending=True)

#transforma o dataset para ver os preços por região e por data
unstack_serie_produto_regiao = pesquisa.groupby('regiao')['valor_venda'].resample('W').mean().unstack(level=0)
unstack_serie_produto_regiao.columns = ['Centrooeste', 'Norte', 'Nordeste', 'Sul', 'Sudeste']
unstack_serie_produto_regiao.head(5)
# Out:
#              Centrooeste     Norte  Nordeste       Sul   Sudeste
# data_coleta
# 2018-01-07      3.567140  3.600000  3.339748  3.224946  3.362675
# 2018-01-14      3.585876  3.622564  3.353091  3.237576  3.369008
# 2018-01-21      3.587215  3.628758  3.392695  3.244406  3.380961
# 2018-01-28      3.586277  3.636516  3.389892  3.249832  3.381619
# 2018-02-04      3.599469  3.644167  3.403660  3.261563  3.388592

# %%
# Create a trace
trace = go.Bar(
    x = unstack_serie_produto_regiao.index,
    y = unstack_serie_produto_regiao.Norte
)
data = [trace]

iplot(data)
# Out:
# <div id="c6bcba1b-04fd-4ca8-b290-46d7b4838121" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("c6bcba1b-04fd-4ca8-b290-46d7b4838121", [{"uid": "355d483f-c262-11e8-a9ef-84ef187225cc", "type": "bar", "x": ["2018-01-07", "2018-01-14", "2018-01-21", "2018-01-28", "2018-02-04", "2018-02-11", "2018-02-18", "2018-02-25", "2018-03-04", "2018-03-11", "2018-03-18", "2018-03-25", "2018-04-01", "2018-04-08", "2018-04-15", "2018-04-22", "2018-04-29", "2018-05-06", "2018-05-13", "2018-05-20", "2018-05-27", "2018-06-03", "2018-06-10", "2018-06-17", "2018-06-24", "2018-07-01", "2018-07-08", "2018-07-15", "2018-07-22", "2018-07-29", "2018-08-
"x": ["2018-01-07", "2018-01-14", "2018-01-21", "2018-01-28", "2018-02-04", "2018-02-11", "2018-02-18", "2018-02-25", "2018-03-04", "2018-03-11", "2018-03-18", "2018-03-25", "2018-04-01", "2018-04-08", "2018-04-15", "20 ...

# %%
# Create a trace
trace = go.Scatter(
    x = unstack_serie_produto_regiao.index,
    y = unstack_serie_produto_regiao.Norte
)

data = [trace]

iplot(data)
# Out:
# <div id="311c1fd9-c47a-47e7-bbb5-a1b565c1b703" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("311c1fd9-c47a-47e7-bbb5-a1b565c1b703", [{"uid": "355d484b-c262-11e8-a9ef-84ef187225cc", "type": "scatter", "x": ["2018-01-07", "2018-01-14", "2018-01-21", "2018-01-28", "2018-02-04", "2018-02-11", "2018-02-18", "2018-02-25", "2018-03-04", "2018-03-11", "2018-03-18", "2018-03-25", "2018-04-01", "2018-04-08", "2018-04-15", "2018-04-22", "2018-04-29", "2018-05-06", "2018-05-13", "2018-05-20", "2018-05-27", "2018-06-03", "2018-06-10", "2018-06-17", "2018-06-24", "2018-07-01", "2018-07-08", "2018-07-15", "2018-07-22", "2018-07-29", "2018-08-05"], "y": [3.6000000000000036, 3.622564102564104, 3.62875778546713, 3.6365164835164854, 3.644166666666666, 3.6427335766423408, 3.662862453531601, 3.6490944055944072, 3.6511824817518277, 3.6447370370370384, 3.6438988764044966, 3.654231060606063, 3.6559710144927564, 3.6748191881918864, 3.686610687022901, 3.693379061371845, 3.7474153846153904, 3.7591684981685023, 3.7868149466192196, 3.8516816479400764, 4.03607450980392, 4.052784615384615, 3.7168709677419383, 3.674015384615385, 3.676457364341083, 3.643620938628156, 3.63602564102564, 3.6377204301075294, 3.652350943396229, 3.6394652777777807, 3.6446752767527673]}], {}, {"showLink": true, "linkText": "Export to plot.ly"})});</script>

# %%
# Create a trace
precos_norte = go.Scatter(
    x = unstack_serie_produto_regiao.index,
    y = unstack_serie_produto_regiao.Norte,
    name = "norte"
)

precos_nordeste = go.Scatter(
    x = unstack_serie_produto_regiao.index,
    y = unstack_serie_produto_regiao.Nordeste,
    name = "nordeste"
)

precos_centrooeste = go.Scatter(
    x = unstack_serie_produto_regiao.index,
    y = unstack_serie_produto_regiao.Centrooeste,
    name = "centro-oeste"
)

precos_sudeste = go.Scatter(
    x = unstack_serie_produto_regiao.index,
    y = unstack_serie_produto_regiao.Sudeste,
    name = "sudeste"
)

precos_sul = go.Scatter(
    x = unstack_serie_produto_regiao.index,
    y = unstack_serie_produto_regiao.Sul,
    name = "sul"
)

data = [precos_norte, precos_nordeste, precos_centrooeste, precos_sudeste, precos_sul]

iplot(data)
# Out:
# <div id="a509a90f-99c5-4e7d-97ee-8cf1207dcc55" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("a509a90f-99c5-4e7d-97ee-8cf1207dcc55", [{"uid": "36bf2af3-c262-11e8-a9ef-84ef187225cc", "type": "scatter", "x": ["2018-01-07", "2018-01-14", "2018-01-21", "2018-01-28", "2018-02-04", "2018-02-11", "2018-02-18", "2018-02-25", "2018-03-04", "2018-03-11", "2018-03-18", "2018-03-25", "2018-04-01", "2018-04-08", "2018-04-15", "2018-04-22", "2018-04-29", "2018-05-06", "2018-05-13", "2018-05-20", "2018-05-27", "2018-06-03", "2018-06-10", "2018-06-17", "2018-06-24", "2018-07-01", "2018-07-08", "2018-07-15", "2018-07-22", "2018-07-29", "2018-08-05"], "name": "norte", "y": [3.6000000000000036, 3.622564102564104, 3.62875778546713, 3.6365164835164854, 3.644166666666666, 3.6427335766423408, 3.662862453531601, 3.6490944055944072, 3.6511824817518277, 3.6447370370370384, 3.6438988764044966, 3.654231060606063, 3.6559710144927564, 3.6748191881918864, 3.686610687022901, 3.693379061371845, 3.7474153846153904, 3.7591684981685023, 3.7868149466192196, 3.8516816479400764, 4.03607450980392, 4.052784615384615, 3.7168709677419383, 3.674015384615385, 3.676457364341083, 3.643620938628156, 3.63602564102564, 3.6377204301075294, 3.652350943396229, 3.6394652777777807, 3.6446752767527673]}, {"uid": "36bf2af4-c262-11e8-a9ef-84ef187225cc", "type": "scatter", "x": ["2018-01-07", "2018-01-14", "2018-01-21", "2018-01-28", "2018-02-04", "2018-02-11", "2018-02-18", "2018-02-25", "2018-03-04", "2018-03-11", "2018-03-18", "2018-03-25", "2018-04-01", "2018-04-08", "2018-04-15", "2018-04-22", "2018-04-29", "2018-05-06", "2018-05-13", "2018-05-20", "2018-05-27", "2018-06-03", "2018-06-10", "2018-06-17", "2018-06-24", "2018-07-01", "2018-07-08", "2018-07-15", "2018-07-22", "2018-07-29", "2018-08-05"], "name": "nordeste", "y": [3.3397477313974595, 3.3530912343470507, 3.392695495495493, 3.389891891891886, 3.403660211267599, 3.4086035714285683, 3.406806569343063, 3.407747779751332, 3.410694642857141, 3.4086648648648645, 3.410848648648646, 3.412796226415095, 3.4171767955801053, 3.430740259740256, 3.4423469387755077, 3.4621249999999923, 3.5073388581952103, 3.527309833024114, 3.597416826003824, 3.6342688766114137, 3.8071057692307644, 3.8824428571428555, 3.5804648187633283, 3.524340725806452, 3.457357707509879, 3.4622743190661405, 3.440893145161289, 3.446021359223297, 3.447052224371365, 3.4414403846153783, 3.439976516634048]}, {"uid": "36bf2af5-c262-11e8-a9ef-84ef187225cc", "type": "scatter", "x": ["2018-01-07", "2018-01-14", "2018-01-21", "2018-01-28", "2018-02-04", "2018-02-11", "2018-02-18", "2018-02-25", "2018-03-04", "2018-03-11", "2018-03-18", "2018-03-25", "2018-04-01", "2018-04-08", "2018-04-15", "2018-04-22", "2018-04-29", "2018-05-06", "2018-05-13", "2018-05-20", "2018-05-27", "2018-06-03", "2018-06-10", "2018-06-17", "2018-06-24", "2018-07-01", "2018-07-08", "2018-07-15", "2018-07-22", "2018-07-29", "2018-08-05"], "name": "centro-oeste", "y": [3.5671398963730603, 3.5858758465011356, 3.587214765100674, 3.586276744186051, 3.5994688221709, 3.5904141876430233, 3.597284116331098, 3.5847061503416833, 3.5888928571428567, 3.580598623853211, 3.5949137168141556, 3.580687772925771, 3.588521739130435, 3.5859955056179764, 3.6026734234234286, 3.616701986754968, 3.6396000000000033, 3.667133333333337, 3.732552106430152, 3.7950066815144723, 3.9807155963302745, 4.03038, 3.728894459102902, 3.664213942307694, 3.613889671361504, 3.5977061503416907, 3.593766292134832, 3.590828375286044, 3.5684268585131935, 3.5716232227488165, 3.558948780487807]}, {"uid": "36bf2af6-c262-11e8-a9ef-84ef187225cc", "type": "scatter", "x": ["2018-01-07", "2018-01-14", "2018-01-21", "2018-01-28", "2018-02-04", "2018-02-11", "2018-02-18", "2018-02-25", "2018-03-04", "2018-03-11", "2018-03-18", "2018-03-25", "2018-04-01", "2018-04-08", " ...

# %%
trace = go.Bar(
    x = pesquisa.estado.unique(),
    y = pesquisa.groupby('estado')['valor_venda'].mean(),
    marker=dict(
        color=['rgba(222,45,38,0.8)', 
               'rgba(204,204,204,1)',
               'rgba(204,204,204,1)', 
               'rgba(204,204,204,1)',
               'rgba(204,204,204,1)',
               'rgba(204,204,204,1)', 
               'rgba(204,204,204,1)',
               'rgba(204,204,204,1)',
               'rgba(204,204,204,1)', 
               'rgba(204,204,204,1)',
               'rgba(204,204,204,1)',
               'rgba(204,204,204,1)', 
               'rgba(204,204,204,1)',
               'rgba(204,204,204,1)',
               'rgba(204,204,204,1)', 
               'rgba(204,204,204,1)',
               'rgba(204,204,204,1)',
               'rgba(222,45,38,0.8)', 
               'rgba(204,204,204,1)',
               'rgba(204,204,204,1)',
               'rgba(204,204,204,1)', 
               'rgba(204,204,204,1)',
               'rgba(204,204,204,1)',
               'rgba(204,204,204,1)', 
               'rgba(204,204,204,1)',
               'rgba(204,204,204,1)',
               'rgba(204,204,204,1)'])
)
layout = go.Layout(
    title='Média de preço por estado')

data = [trace]

fig = go.Figure(data=data, layout=layout)

iplot(fig)
# Out:
# <div id="eb5c2a27-500a-49ab-9a09-ac26a8d12989" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("eb5c2a27-500a-49ab-9a09-ac26a8d12989", [{"marker": {"color": ["rgba(222,45,38,0.8)", "rgba(204,204,204,1)", "rgba(204,204,204,1)", "rgba(204,204,204,1)", "rgba(204,204,204,1)", "rgba(204,204,204,1)", "rgba(204,204,204,1)", "rgba(204,204,204,1)", "rgba(204,204,204,1)", "rgba(204,204,204,1)", "rgba(204,204,204,1)", "rgba(204,204,204,1)", "rgba(204,204,204,1)", "rgba(204,204,204,1)", "rgba(204,204,204,1)", "rgba(204,204,204,1)", "rgba(204,204,204,1)", "rgba(222,45,38,0.8)", "rgba(204,204,204,1)", "rgba(204,204,204,1)", "rgba(204,204,204,1)", "rgba(204,204,204,1)", "rgba(204,204,204,1)", "rgba(204,204,204,1)", "rgba(204,204,204,1)", "rgba(204,204,204,1)", "rgba(204,204,204,1)"]}, "type": "bar", "x": ["RS", "GO", "MG", "SP", "TO", "PR", "RJ", "AL", "AP", "RR", "BA", "SC", "RO", "PA", "MA", "CE", "AC", "PI", "PB", "MT", "AM", "PE", "SE", "MS", "RN", "DF", "ES"], "uid": "36bf2af8-c262-11e8-a9ef-84ef187225cc", "y": [4.1989413953488155, 3.4964704830053623, 3.546467964314671, 3.878100740740755, 3.4355608035577982, 3.597921052631593, 3.6746718555417064, 3.361333939118558, 3.55626028734831, 3.4002235793946096, 3.516644045534132, 3.6966048484848493, 3.741190529455615, 3.6435027214250284, 3.35978941565601, 3.415283430232553, 3.5027803365810413, 3.2365837937385287, 3.558639170284577, 3.501401296829977, 3.62074252753014, 3.5276993865030715, 3.345701929949995, 3.2712568272476363, 3.433112167300374, 3.331204153065695, 3.4108740499456927]}], {"title": "M\u00e9dia de pre\u00e7o por estado"}, {"showLink": true, "linkText": "Export to plot.ly"})});</script>
